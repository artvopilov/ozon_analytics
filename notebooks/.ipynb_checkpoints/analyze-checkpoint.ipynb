# %%
import pandas as pd

from pathlib import Path

# %%
pd.set_option('display.max_colwidth', None)

# %%
REPORT_DIR = '/Users/artemvopilov/Documents/Ozon'
REPORT_NAME = 'report_goods_20231201_20240114.xlsx'

# %% [markdown]
# ### Read data

# %%
report_path = Path(REPORT_DIR, REPORT_NAME)

# %%
report_df = pd.read_excel(report_path, engine='openpyxl', sheet_name='Начисления', parse_dates=True)
# Out:
# /Users/artemvopilov/Business/ozon_analytics/.venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# ### Describe

# %%
report_df.columns
# Out:
# Index(['Дата начисления', 'Тип начисления',
#        'Номер отправления или идентификатор услуги',
#        'Дата принятия заказа в обработку или оказания услуги',
#        'Склад отгрузки', 'SKU', 'Артикул', 'Название товара или услуги',
#        'Количество', 'За продажу или возврат до вычета комиссий и услуг',
#        'Ставка комиссии', 'Комиссия за продажу', 'Сборка заказа',
#        'Обработка отправления (Drop-off/Pick-up) (разбивается по товарам пропорционально количеству в отправлении)',
#        'Магистраль',
#        'Последняя миля (разбивается по товарам пропорционально доле цены товара в сумме отправления)',
#        'Обратная магистраль', 'Обработка возврата',
#        'Обработка отмененного или невостребованного товара (разбивается по товарам в отправлении в одинаковой пропорции)',
#        'Обработка невыкупленного товара', 'Логистика', 'Индекс локализации',
#        'Обратная логистика', 'Итого'],
#       dtype='object')

# %%
report_df.dtypes
# Out:
# Дата начисления                                                                                                     datetime64[ns]
# Тип начисления                                                                                                              object
# Номер отправления или идентификатор услуги                                                                                  object
# Дата принятия заказа в обработку или оказания услуги                                                                datetime64[ns]
# Склад отгрузки                                                                                                              object
# SKU                                                                                                                        float64
# Артикул                                                                                                                    float64
# Название товара или услуги                                                                                                  object
# Количество                                                                                                                   int64
# За продажу или возврат до вычета комиссий и услуг                                                                            int64
# Ставка комиссии                                                                                                            float64
# Комиссия за продажу                                                                                                        float64
# Сборка заказа                                                                                                                int64
# Обработка отправления (Drop-off/Pick-up) (разбивается по товарам пропорционально количеству в отправлении)                   int64
# Магистраль                                                                                                                   int64
# Последняя миля (разбивается по товарам пропорционально доле цены товара в сумме отправления)                               float64
# Обратная магистраль                                                                                                          int64
# Обработка возврата                                                                                                           int64
# Обработка отмененного или невостребованного товара (разбивается по товарам в отправлении в одинаковой пропорции)             int64
# Обработка невыкупленного товара                                                                                              int64
# Логистика                                                                                                                  float64
# Индекс локализации                                                                                                         float64
# Обратная логистика                                                                                                           int64
# Итого                                                                                                                      float64
# dtype: object

# %%
report_df.head()
# Out:
#   Дата начисления                                   Тип начисления  \
# 0      2023-12-01  Доставка и обработка возврата, отмены, невыкупа
# 1      2023-12-01  Доставка и обработка возврата, отмены, невыкупа
# 2      2023-12-01  Доставка и обработка возврата, отмены, невыкупа
# 3      2023-12-01                              Доставка покупателю
# 4      2023-12-01                              Доставка покупателю
#
#   Номер отправления или идентификатор услуги  \
# 0                            46593954-0044-1
# 1                            46593954-0044-1
# 2                            23545563-0150-9
# 3                            51086215-0024-1
# 4                            80849669-0112-2
#
#   Дата принятия заказа в обработку или оказания услуги Склад отгрузки  \
# 0                                2023-11-20 08:29:30              FBO
# 1                                2023-11-20 08:29:30              FBO
# 2                                2023-11-15 00:15:18              FBO
# 3                                2023-11-12 02:42:38              FBO
# 4                                2023-11-29 14:56:22              FBO
#
#             SKU  Артикул                         Название товара или услуги  \
# 0  1.211572e+09   9004.0  Зарядное устройство для Sumsung, Xiaomi, Huawe...
# 1  1.211572e+09   9004.0  Зарядное устройство для Sumsung, Xiaomi, Huawe...
# 2  1.211572e+09   9003.0  Зарядное устройство для iPhone, iPad, AirPods....
# 3  1.211572e+09   9003.0  Зарядное устройство для iPhone, iPad, AirPods....
# 4  1.211572e+09   9003.0  Зарядное устройство для iPhone, iPad, AirPods....
#
#    Количество  За продажу или возврат до вычета комиссий и услуг  ...  \
# 0           1                                                  0  ...
# 1           1                                                  0  ...
# 2           1                                                  0  ...
# 3           1                                                478  ...
# 4           1                                                672  ...
#
#    Магистраль  \
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#
#    Последняя миля (разбивается по товарам пропорционально доле цены товара в сумме отправления)  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
# 3                                              -7.03
# 4                                             -31.80
#
#    Обратная магистраль  Обработка возврата  \
# 0                    0                   0
# 1                    0                 -15
# 2                    0                 -65
# 3                    0                   0
# 4                    0                   0
#
#    Обработка отмененного или невостребованного товара (разбивается по товарам в отправлении в одинаковой пропорции)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Обработка невыкупленного товара  Логистика  Индекс локализации  \
# 0                                0      -63.8                62.0
# 1                              -50        0.0                 NaN
# 2                                0        0.0                 NaN
# 3                                0      -63.8                61.0
# 4                                0      -63.8                62.0
#
#    Обратная логистика   Итого
# 0                   0  -63.80
# 1                 -58 -123.00
# 2                 -58 -123.00
# 3                   0  318.74
# 4                   0  452.08
#
# [5 rows x 24 columns]

# %%
report_df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 24 columns):
#  #   Column                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                            --------------  -----
#  0   Дата начисления                                                                                                   196 non-null    datetime64[ns]
#  1   Тип начисления                                                                                                    196 non-null    object
#  2   Номер отправления или идентификатор услуги                                                                        167 non-null    object
#  3   Дата принятия заказа в обработку или оказания услуги                                                              196 non-null    datetime64[ns]
#  4   Склад отгрузки                                                                                                    84 non-null     object
#  5   SKU                                                                                                               166 non-null    float64
#  6   Артикул                                                                                                           166 non-null    float64
#  7   Название товара или услуги                                                                                        188 non-null    object
#  8   Количество                                                                                                        196 non-null    int64
#  9   За продажу или возврат до вычета комиссий и услуг                                                                 196 non-null    int64
#  10  Ставка комиссии                                                                                                   196 non-null    float64
#  11  Комиссия за продажу                                                                                               196 non-null    float64
#  12  Сборка заказа                                                                                                     196 non-null    int64
#  13  Обработка отправления (Drop-off/Pick-up) (разбивается по товарам пропорционально количеству в отправлении)        196 non-null    int64
#  14  Магистраль                                                                                                        196 non-null    int64
#  15  Последняя миля (разбивается по товарам пропорционально доле цены товара в сумме отправления)                      196 non-null    float64
#  16  Обратная магистраль                                                                                               196 non-null    int64
#  17  Обработка возврата                                                                                                196 non-null    int64
#  18  Обработка отмененного или невостребованного товара (разбивается по товарам в отправлении в одинаковой пропорции)  196 non-null    int64
#  19  Обработка невыкупленного товара                                                                                   196 non-null    int64
#  20  Логистика                                                                                                         196 non-null    float64
#  21  Индекс локализации                                                                                                82 non-null     float64
#  22  Обратная логистика                                                                                                196 non-null    int64
#  23  Итого                                                                                                             196 non-null    float64
# dtypes: datetime64[ns](2), float64(8), int64(10), object(4)
# memory usage: 36.9+ KB

# %%
report_df.describe(include='all')
# Out:
#                       Дата начисления     Тип начисления  \
# count                             196                196
# unique                            NaN                  7
# top                               NaN  Оплата эквайринга
# freq                              NaN                 82
# mean    2023-12-23 00:14:41.632653056                NaN
# min               2023-12-01 00:00:00                NaN
# 25%               2023-12-10 00:00:00                NaN
# 50%               2023-12-19 00:00:00                NaN
# 75%               2024-01-06 06:00:00                NaN
# max               2024-01-14 00:00:00                NaN
# std                               NaN                NaN
#
#        Номер отправления или идентификатор услуги  \
# count                                         167
# unique                                        159
# top                               46593954-0044-1
# freq                                            2
# mean                                          NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
# std                                           NaN
#
#        Дата принятия заказа в обработку или оказания услуги Склад отгрузки  \
# count                                                 196               84
# unique                                                NaN                1
# top                                                   NaN              FBO
# freq                                                  NaN               84
# mean                        2023-12-21 01:28:19.214285568              NaN
# min                                   2023-11-12 02:42:38              NaN
# 25%                                   2023-12-09 15:01:34              NaN
# 50%                            2023-12-17 20:04:21.500000              NaN
# 75%                            2024-01-05 17:54:08.500000              NaN
# max                                   2024-01-13 11:39:58              NaN
# std                                                   NaN              NaN
#
#                  SKU      Артикул  \
# count   1.660000e+02   166.000000
# unique           NaN          NaN
# top              NaN          NaN
# freq             NaN          NaN
# mean    1.260451e+09  9008.644578
# min     1.201776e+09  9001.000000
# 25%     1.201776e+09  9001.000000
# 50%     1.297355e+09  9005.000000
# 75%     1.309528e+09  9011.000000
# max     1.325099e+09  9101.000000
# std     4.962893e+07    15.431968
#
#                                Название товара или услуги  Количество  \
# count                                                 188  196.000000
# unique                                                 32         NaN
# top     Держатель кухонный для разделочных досок, для ...         NaN
# freq                                                   49         NaN
# mean                                                  NaN    0.933673
# min                                                   NaN    0.000000
# 25%                                                   NaN    1.000000
# 50%                                                   NaN    1.000000
# 75%                                                   NaN    1.000000
# max                                                   NaN    5.000000
# std                                                   NaN    0.573508
#
#         За продажу или возврат до вычета комиссий и услуг  ...  Магистраль  \
# count                                          196.000000  ...       196.0
# unique                                                NaN  ...         NaN
# top                                                   NaN  ...         NaN
# freq                                                  NaN  ...         NaN
# mean                                           145.801020  ...         0.0
# min                                              0.000000  ...         0.0
# 25%                                              0.000000  ...         0.0
# 50%                                              0.000000  ...         0.0
# 75%                                            152.000000  ...         0.0
# max                                           1012.000000  ...         0.0
# std                                            252.074035  ...         0.0
#
#         Последняя миля (разбивается по товарам пропорционально доле цены товара в сумме отправления)  \
# count                                          196.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                            -6.919898
# min                                            -43.750000
# 25%                                             -8.360000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                              0.000000
# std                                             11.747969
#
#         Обратная магистраль  Обработка возврата  \
# count                 196.0          196.000000
# unique                  NaN                 NaN
# top                     NaN                 NaN
# freq                    NaN                 NaN
# mean                    0.0           -0.408163
# min                     0.0          -65.000000
# 25%                     0.0            0.000000
# 50%                     0.0            0.000000
# 75%                     0.0            0.000000
# max                     0.0            0.000000
# std                     0.0            4.759523
#
#         Обработка отмененного или невостребованного товара (разбивается по товарам в отправлении в одинаковой пропорции)  \
# count                                               196.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                                  0.0
# min                                                   0.0
# 25%                                                   0.0
# 50%                                                   0.0
# 75%                                                   0.0
# max                                                   0.0
# std                                                   0.0
#
#         Обработка невыкупленного товара   Логистика  Индекс локализации  \
# count                        196.000000  196.000000           82.000000
# unique                              NaN         NaN                 NaN
# top                                 NaN         NaN                 NaN
# freq                                NaN         NaN                 NaN
# mean                          -0.255102  -28.986224           53.121951
# min                          -50.000000 -226.800000           20.000000
# 25%                            0.000000  -63.800000           38.000000
# 50%                            0.000000    0.000000           60.000000
# 75%                            0.000000    0.000000           62.000000
# max                            0.000000    0.000000           77.000000
# std                            3.571429   36.345840           15.402734
#
#         Обратная логистика       Итого
# count           196.000000  196.000000
# unique                 NaN         NaN
# top                    NaN         NaN
# freq                   NaN         NaN
# mean             -0.591837   63.065918
# min             -58.000000 -550.000000
# 25%               0.000000   -8.380000
# 50%               0.000000   -1.810000
# 75%               0.000000   53.092500
# max               0.000000  720.610000
# std               5.843843  196.566227
#
# [11 rows x 24 columns]

# %% [markdown]
# ### Statistics

# %%
report_df['Итого'].sum()
# Out:
# 12360.919999999998

# %%
report_df['Итого'].sum()

# %%
report_df.groupby('Тип начисления', as_index=False).agg(Sum=('Итого', 'sum'))
# Out:
#                                     Тип начисления       Sum
# 0  Доставка и обработка возврата, отмены, невыкупа   -309.80
# 1                              Доставка покупателю  16452.17
# 2     Обработка товара в составе грузоместа на FBO      0.00
# 3                                Оплата эквайринга   -272.95
# 4                Приобретение отзывов на платформе  -1512.00
# 5                       Услуги продвижения товаров  -1921.50
# 6                                       Утилизация    -75.00

# %%
report_df\
    .where(report_df['Тип начисления'] == 'Доставка покупателю')\
    .groupby('Название товара или услуги', as_index=False)\
    .agg(Sum=('Итого', 'sum'))
# Out:
#                                                                                                                               Название товара или услуги  \
# 0                                                    Держатель кухонный для разделочных досок, для сковород, тарелок, кастрюль, 3 см х 5 см х 5 см, 1 шт
# 1                   Зарядное устройство для Sumsung, Xiaomi, Huawei, Honor. Адаптер 20W, кабель USB Type-C to USB Type-C, 1 метр белый. Быстрая зарядка.
# 2  Зарядное устройство для Sumsung, Xiaomi, Huawei, Honor. Адаптер 20W, кабель USB Type-C to USB Type-C, 1 метр белый. Быстрая зарядка.. Уцененный товар
# 3                             Зарядное устройство для iPhone, iPad, AirPods. Адаптер 20W, кабель Lightning to USB Type-C, 1 метр белый. Быстрая зарядка.
# 4                                                                          Кабель Lightning to USB Type-C. Провод Lightning to USB Type-C. 1 метр белый.
# 5                                                                        Кабель USB Type-C to USB Type-C. Провод USB Type-C to USB Type-C. 1 метр белый.
# 6                                                                                           Органайзер для хранения вещей. 36 х 25 х 20 см, 7 отделений.
# 7                                                                                     Органайзер для хранения вещей. 36 х 25 х 20 см, 7 отделений. 2 шт.
# 8                                                                                                          Электронные кухонные весы кухонныевесы, белый
#
#        Sum
# 0  1252.55
# 1  1753.49
# 2   425.43
# 3  4441.09
# 4   148.65
# 5   723.06
# 6  -177.00
# 7  7330.71
# 8   554.19
